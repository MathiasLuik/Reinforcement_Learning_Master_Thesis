# %%
import alpaca_trade_api as tradeapi
import threading
import time
import datetime

API_KEY = "PKBZDO2KCJZ4JLLWPAPO"
API_SECRET = "dkr5S5N5QkRpELpL/TRVV5Jd0sLFhNY63C8EOuho"
APCA_API_BASE_URL = "https://paper-api.alpaca.markets"


class LongShort:
  def __init__(self):
    self.alpaca = tradeapi.REST(API_KEY, API_SECRET, APCA_API_BASE_URL, 'v2')

    stockUniverse = ['DOMO', 'TLRY', 'SQ', 'MRO', 'AAPL', 'GM', 'SNAP', 'SHOP', 'SPLK', 'BA', 'AMZN', 'SUI', 'SUN', 'TSLA', 'CGC', 'SPWR', 'NIO', 'CAT', 'MSFT', 'PANW', 'OKTA', 'TWTR', 'TM', 'RTN', 'ATVI', 'GS', 'BAC', 'MS', 'TWLO', 'QCOM', ]
    # Format the allStocks variable for use in the class.
    self.allStocks = []
    for stock in stockUniverse:
      self.allStocks.append([stock, 0])

    self.long = []
    self.short = []
    self.qShort = None
    self.qLong = None
    self.adjustedQLong = None
    self.adjustedQShort = None
    self.blacklist = set()
    self.longAmount = 0
    self.shortAmount = 0
    self.timeToClose = None

  def run(self):
    # First, cancel any existing orders so they don't impact our buying power.
    orders = self.alpaca.list_orders(status="open")
    for order in orders:
      self.alpaca.cancel_order(order.id)

    # Wait for market to open.
    print("Waiting for market to open...")
    tAMO = threading.Thread(target=self.awaitMarketOpen)
    tAMO.start()
    tAMO.join()
    print("Market opened.")

    # Rebalance the portfolio every minute, making necessary trades.
    while True:

      # Figure out when the market will close so we can prepare to sell beforehand.
      clock = self.alpaca.get_clock()
      closingTime = clock.next_close.replace(tzinfo=datetime.timezone.utc).timestamp()
      currTime = clock.timestamp.replace(tzinfo=datetime.timezone.utc).timestamp()
      self.timeToClose = closingTime - currTime

      if(self.timeToClose < (60 * 15)):
        # Close all positions when 15 minutes til market close.
        print("Market closing soon.  Closing positions.")

        positions = self.alpaca.list_positions()
        for position in positions:
          if(position.side == 'long'):
            orderSide = 'sell'
          else:
            orderSide = 'buy'
          qty = abs(int(float(position.qty)))
          respSO = []
          tSubmitOrder = threading.Thread(target=self.submitOrder(qty, position.symbol, orderSide, respSO))
          tSubmitOrder.start()
          tSubmitOrder.join()

        # Run script again after market close for next trading day.
        print("Sleeping until market close (15 minutes).")
        time.sleep(60 * 15)
      else:
        # Rebalance the portfolio.
        tRebalance = threading.Thread(target=self.rebalance)
        tRebalance.start()
        tRebalance.join()
        time.sleep(60)

  # Wait for market to open.
  def awaitMarketOpen(self):
    isOpen = self.alpaca.get_clock().is_open
    while(not isOpen):
      clock = self.alpaca.get_clock()
      openingTime = clock.next_open.replace(tzinfo=datetime.timezone.utc).timestamp()
      currTime = clock.timestamp.replace(tzinfo=datetime.timezone.utc).timestamp()
      timeToOpen = int((openingTime - currTime) / 60)
      print(str(timeToOpen) + " minutes til market open.")
      time.sleep(60)
      isOpen = self.alpaca.get_clock().is_open

  def rebalance(self):
    tRerank = threading.Thread(target=self.rerank)
    tRerank.start()
    tRerank.join()

    # Clear existing orders again.
    orders = self.alpaca.list_orders(status="open")
    for order in orders:
      self.alpaca.cancel_order(order.id)

    print("We are taking a long position in: " + str(self.long))
    print("We are taking a short position in: " + str(self.short))
    # Remove positions that are no longer in the short or long list, and make a list of positions that do not need to change.  Adjust position quantities if needed.
    executed = [[], []]
    positions = self.alpaca.list_positions()
    self.blacklist.clear()
    for position in positions:
      if(self.long.count(position.symbol) == 0):
        # Position is not in long list.
        if(self.short.count(position.symbol) == 0):
          # Position not in short list either.  Clear position.
          if(position.side == "long"):
            side = "sell"
          else:
            side = "buy"
          respSO = []
          tSO = threading.Thread(target=self.submitOrder, args=[abs(int(float(position.qty))), position.symbol, side, respSO])
          tSO.start()
          tSO.join()
        else:
          # Position in short list.
          if(position.side == "long"):
            # Position changed from long to short.  Clear long position to prepare for short position.
            side = "sell"
            respSO = []
            tSO = threading.Thread(target=self.submitOrder, args=[int(float(position.qty)), position.symbol, side, respSO])
            tSO.start()
            tSO.join()
          else:
            if(abs(int(float(position.qty))) == self.qShort):
              # Position is where we want it.  Pass for now.
              pass
            else:
              # Need to adjust position amount
              diff = abs(int(float(position.qty))) - self.qShort
              if(diff > 0):
                # Too many short positions.  Buy some back to rebalance.
                side = "buy"
              else:
                # Too little short positions.  Sell some more.
                side = "sell"
              respSO = []
              tSO = threading.Thread(target=self.submitOrder, args=[abs(diff), position.symbol, side, respSO])
              tSO.start()
              tSO.join()
            executed[1].append(position.symbol)
            self.blacklist.add(position.symbol)
      else:
        # Position in long list.
        if(position.side == "short"):
          # Position changed from short to long.  Clear short position to prepare for long position.
          respSO = []
          tSO = threading.Thread(target=self.submitOrder, args=[abs(int(float(position.qty))), position.symbol, "buy", respSO])
          tSO.start()
          tSO.join()
        else:
          if(int(float(position.qty)) == self.qLong):
            # Position is where we want it.  Pass for now.
            pass
          else:
            # Need to adjust position amount.
            diff = abs(int(float(position.qty))) - self.qLong
            if(diff > 0):
              # Too many long positions.  Sell some to rebalance.
              side = "sell"
            else:
              # Too little long positions.  Buy some more.
              side = "buy"
            respSO = []
            tSO = threading.Thread(target=self.submitOrder, args=[abs(diff), position.symbol, side, respSO])
            tSO.start()
            tSO.join()
          executed[0].append(position.symbol)
          self.blacklist.add(position.symbol)

    # Send orders to all remaining stocks in the long and short list.
    respSendBOLong = []
    tSendBOLong = threading.Thread(target=self.sendBatchOrder, args=[self.qLong, self.long, "buy", respSendBOLong])
    tSendBOLong.start()
    tSendBOLong.join()
    respSendBOLong[0][0] += executed[0]
    if(len(respSendBOLong[0][1]) > 0):
      # Handle rejected/incomplete orders and determine new quantities to purchase.
      respGetTPLong = []
      tGetTPLong = threading.Thread(target=self.getTotalPrice, args=[respSendBOLong[0][0], respGetTPLong])
      tGetTPLong.start()
      tGetTPLong.join()
      if (respGetTPLong[0] > 0):
        self.adjustedQLong = self.longAmount // respGetTPLong[0]
      else:
        self.adjustedQLong = -1
    else:
      self.adjustedQLong = -1

    respSendBOShort = []
    tSendBOShort = threading.Thread(target=self.sendBatchOrder, args=[self.qShort, self.short, "sell", respSendBOShort])
    tSendBOShort.start()
    tSendBOShort.join()
    respSendBOShort[0][0] += executed[1]
    if(len(respSendBOShort[0][1]) > 0):
      # Handle rejected/incomplete orders and determine new quantities to purchase.
      respGetTPShort = []
      tGetTPShort = threading.Thread(target=self.getTotalPrice, args=[respSendBOShort[0][0], respGetTPShort])
      tGetTPShort.start()
      tGetTPShort.join()
      if(respGetTPShort[0] > 0):
        self.adjustedQShort = self.shortAmount // respGetTPShort[0]
      else:
        self.adjustedQShort = -1
    else:
      self.adjustedQShort = -1

    # Reorder stocks that didn't throw an error so that the equity quota is reached.
    if(self.adjustedQLong > -1):
      self.qLong = int(self.adjustedQLong - self.qLong)
      for stock in respSendBOLong[0][0]:
        respResendBOLong = []
        tResendBOLong = threading.Thread(target=self.submitOrder, args=[self.qLong, stock, "buy", respResendBOLong])
        tResendBOLong.start()
        tResendBOLong.join()

    if(self.adjustedQShort > -1):
      self.qShort = int(self.adjustedQShort - self.qShort)
      for stock in respSendBOShort[0][0]:
        respResendBOShort = []
        tResendBOShort = threading.Thread(target=self.submitOrder, args=[self.qShort, stock, "sell", respResendBOShort])
        tResendBOShort.start()
        tResendBOShort.join()

  # Re-rank all stocks to adjust longs and shorts.
  def rerank(self):
    tRank = threading.Thread(target=self.rank)
    tRank.start()
    tRank.join()

    # Grabs the top and bottom quarter of the sorted stock list to get the long and short lists.
    longShortAmount = len(self.allStocks) // 4
    self.long = []
    self.short = []
    for i, stockField in enumerate(self.allStocks):
      if(i < longShortAmount):
        self.short.append(stockField[0])
      elif(i > (len(self.allStocks) - 1 - longShortAmount)):
        self.long.append(stockField[0])
      else:
        continue

    # Determine amount to long/short based on total stock price of each bucket.
    equity = int(float(self.alpaca.get_account().equity))

    self.shortAmount = equity * 0.30
    self.longAmount = equity + self.shortAmount

    respGetTPLong = []
    tGetTPLong = threading.Thread(target=self.getTotalPrice, args=[self.long, respGetTPLong])
    tGetTPLong.start()
    tGetTPLong.join()

    respGetTPShort = []
    tGetTPShort = threading.Thread(target=self.getTotalPrice, args=[self.short, respGetTPShort])
    tGetTPShort.start()
    tGetTPShort.join()

    self.qLong = int(self.longAmount // respGetTPLong[0])
    self.qShort = int(self.shortAmount // respGetTPShort[0])

  # Get the total price of the array of input stocks.
  def getTotalPrice(self, stocks, resp):
    totalPrice = 0
    for stock in stocks:
      bars = self.alpaca.get_barset(stock, "minute", 1)
      totalPrice += bars[stock][0].c
    resp.append(totalPrice)

  # Submit a batch order that returns completed and uncompleted orders.
  def sendBatchOrder(self, qty, stocks, side, resp):
    executed = []
    incomplete = []
    for stock in stocks:
      if(self.blacklist.isdisjoint({stock})):
        respSO = []
        tSubmitOrder = threading.Thread(target=self.submitOrder, args=[qty, stock, side, respSO])
        tSubmitOrder.start()
        tSubmitOrder.join()
        if(not respSO[0]):
          # Stock order did not go through, add it to incomplete.
          incomplete.append(stock)
        else:
          executed.append(stock)
        respSO.clear()
    resp.append([executed, incomplete])

  # Submit an order if quantity is above 0.
  def submitOrder(self, qty, stock, side, resp):
    if(qty > 0):
      try:
        self.alpaca.submit_order(stock, qty, side, "market", "day")
        print("Market order of | " + str(qty) + " " + stock + " " + side + " | completed.")
        resp.append(True)
      except:
        print("Order of | " + str(qty) + " " + stock + " " + side + " | did not go through.")
        resp.append(False)
    else:
      print("Quantity is 0, order of | " + str(qty) + " " + stock + " " + side + " | not completed.")
      resp.append(True)

  # Get percent changes of the stock prices over the past 10 minutes.
  def getPercentChanges(self):
    length = 10
    for i, stock in enumerate(self.allStocks):
      bars = self.alpaca.get_barset(stock[0], 'minute', length)
      self.allStocks[i][1] = (bars[stock[0]][len(bars[stock[0]]) - 1].c - bars[stock[0]][0].o) / bars[stock[0]][0].o

  # Mechanism used to rank the stocks, the basis of the Long-Short Equity Strategy.
  def rank(self):
    # Ranks all stocks by percent change over the past 10 minutes (higher is better).
    tGetPC = threading.Thread(target=self.getPercentChanges)
    tGetPC.start()
    tGetPC.join()

    # Sort the stocks in place by the percent change field (marked by pc).
    self.allStocks.sort(key=lambda x: x[1])

# Run the LongShort class
ls = LongShort()
ls.run()
# Out:
# Waiting for market to open...
# Market opened.
# We are taking a long position in: ['SNAP', 'SUN', 'CGC', 'DOMO', 'TLRY', 'SPWR', 'NIO']
# We are taking a short position in: ['RTN', 'SUI', 'AMZN', 'GS', 'PANW', 'GM', 'QCOM']
# Market order of | 66 TSLA sell | completed.
# Market order of | 1007 SUN buy | completed.
# Market order of | 12 SPWR buy | completed.
# Market order of | 66 SPLK sell | completed.
# Market order of | 66 SHOP sell | completed.
# Market order of | 66 RTN sell | completed.
# Market order of | 66 OKTA sell | completed.
# Market order of | 1007 NIO buy | completed.
# Market order of | 12 MS buy | completed.
# Market order of | 12 DOMO buy | completed.
# Market order of | 12 BAC buy | completed.
# Market order of | 3 AMZN buy | completed.
# Market order of | 1073 SNAP buy | completed.
# Market order of | 1073 CGC buy | completed.
# Market order of | 1073 DOMO buy | completed.
# Market order of | 1073 TLRY buy | completed.
# Market order of | 1073 SPWR buy | completed.
# Market order of | 9 RTN sell | completed.
# Market order of | 9 SUI sell | completed.
# Market order of | 9 GS sell | completed.
# Market order of | 9 PANW sell | completed.
# Market order of | 9 GM sell | completed.
# Market order of | 9 QCOM sell | completed.
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 1336, in getresponse
#     response.begin()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 275, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\util\retry.py", line 368, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\packages\six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\urllib3\connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 1336, in getresponse
#     response.begin()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\http\client.py", line 275, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Mathias Luik\Anaconda3\Lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-1-f1a638e26fe1>", line 312, in getPercentChanges
#     bars = self.alpaca.get_barset(stock[0], 'minute', length)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\alpaca_trade_api\rest.py", line 359, in get_barset
#     resp = self.data_get('/bars/{}'.format(timeframe), params)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\alpaca_trade_api\rest.py", line 166, in data_get
#     'GET', path, data, base_url=base_url, api_version='v1'
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\alpaca_trade_api\rest.py", line 115, in _request
#     return self._one_request(method, url, opts, retry)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\alpaca_trade_api\rest.py", line 134, in _one_request
#     resp = self._session.request(method, url, **opts)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Mathias Luik\Anaconda3\envs\mathias_thesis_alpaca\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# We are taking a long position in: ['SNAP', 'SUN', 'CGC', 'DOMO', 'TLRY', 'SPWR', 'NIO']
# We are taking a short position in: ['RTN', 'SUI', 'AMZN', 'GS', 'PANW', 'GM', 'QCOM']
# Market order of | 1 TLRY sell | completed.
# Market order of | 1 SUN sell | completed.
# Market order of | 1 SPWR sell | completed.
# Market order of | 1 SNAP sell | completed.
# Market order of | 1 NIO sell | completed.
# Market order of | 1 DOMO sell | completed.
# Market order of | 1 CGC sell | completed.
# We are taking a long position in: ['TSLA', 'SUN', 'CGC', 'OKTA', 'DOMO', 'TLRY', 'NIO']
# We are taking a short position in: ['RTN', 'GS', 'SUI', 'GM', 'AMZN', 'BA', 'SQ']
# Market order of | 955 TLRY sell | completed.
# Market order of | 955 SUN sell | completed.
# Market order of | 1072 SPWR sell | completed.
# Market order of | 1072 SNAP sell | completed.
# Market order of | 9 QCOM buy | completed.
# Market order of | 9 PANW buy | completed.
# Market order of | 955 NIO sell | completed.
# Market order of | 955 DOMO sell | completed.
# Market order of | 955 CGC sell | completed.
# Market order of | 117 TSLA buy | completed.
# Market order of | 117 OKTA buy | completed.
# Market order of | 9 BA sell | completed.
# Market order of | 9 SQ sell | completed.
# We are taking a long position in: ['QCOM', 'SUN', 'OKTA', 'CGC', 'TLRY', 'DOMO', 'NIO']
# We are taking a short position in: ['RTN', 'SUI', 'GM', 'GS', 'SQ', 'BA', 'ATVI']
# Market order of | 117 TSLA sell | completed.
# Market order of | 291 TLRY buy | completed.
# Market order of | 291 SUN buy | completed.
# Market order of | 18 SUI sell | completed.
# Market order of | 18 SQ sell | completed.
# Market order of | 18 RTN sell | completed.
# Market order of | 291 OKTA buy | completed.
# Market order of | 291 NIO buy | completed.
# Market order of | 18 GS sell | completed.
# Market order of | 18 GM sell | completed.
# Market order of | 291 DOMO buy | completed.
# Market order of | 291 CGC buy | completed.
# Market order of | 18 BA sell | completed.
# Market order of | 9 AMZN buy | completed.
# Market order of | 408 QCOM buy | completed.
# Market order of | 27 ATVI sell | completed.
# We are taking a long position in: ['QCOM', 'OKTA', 'SUN', 'CGC', 'TLRY', 'DOMO', 'NIO']
# We are taking a short position in: ['RTN', 'SPWR', 'GS', 'GM', 'SUI', 'BA', 'SQ']
# Market order of | 1 TLRY sell | completed.
# Market order of | 1 SUN sell | completed.
# Market order of | 1 SUI sell | completed.
# Market order of | 1 SQ sell | completed.
# Market order of | 1 RTN sell | completed.
# Market order of | 1 QCOM sell | completed.
# Market order of | 1 OKTA sell | completed.
# Market order of | 1 NIO sell | completed.
# Market order of | 1 GS sell | completed.
# Market order of | 1 GM sell | completed.
# Market order of | 1 DOMO sell | completed.
# Market order of | 1 CGC sell | completed.
# Market order of | 1 BA sell | completed.
# Market order of | 27 ATVI buy | completed.
# Market order of | 28 SPWR sell | completed.
# We are taking a long position in: ['QCOM', 'SUN', 'CGC', 'OKTA', 'TLRY', 'DOMO', 'NIO']
# We are taking a short position in: ['GM', 'SPWR', 'GS', 'RTN', 'SUI', 'MRO', 'BA']
# Market order of | 2 SUI sell | completed.
# Market order of | 28 SQ buy | completed.
# Market order of | 2 SPWR sell | completed.
# Market order of | 2 RTN sell | completed.
# Market order of | 2 GS sell | completed.
# Market order of | 2 GM sell | completed.
# Market order of | 2 BA sell | completed.
# Market order of | 30 MRO sell | completed.
# We are taking a long position in: ['TSLA', 'SQ', 'QCOM', 'OKTA', 'TLRY', 'DOMO', 'NIO']
# We are taking a short position in: ['SPWR', 'CGC', 'GM', 'SPLK', 'RTN', 'GS', 'MRO']
# Market order of | 302 TLRY sell | completed.
# Market order of | 407 SUN sell | completed.
# Market order of | 30 SUI buy | completed.
# Market order of | 14 SPWR sell | completed.
# Market order of | 14 RTN sell | completed.
# Market order of | 302 QCOM sell | completed.
# Market order of | 302 OKTA sell | completed.
# Market order of | 302 NIO sell | completed.
# Market order of | 14 MRO sell | completed.
# Market order of | 14 GS sell | completed.
# Market order of | 14 GM sell | completed.
# Market order of | 302 DOMO sell | completed.
# Market order of | 407 CGC sell | completed.
# Market order of | 30 BA buy | completed.
# Market order of | 105 TSLA buy | completed.
# Market order of | 105 SQ buy | completed.
# Order of | 44 CGC sell | did not go through.
# Market order of | 44 SPLK sell | completed.
# Market order of | 1 SPLK sell | completed.
# Market order of | 1 SPWR sell | completed.
# Market order of | 1 RTN sell | completed.
# Market order of | 1 MRO sell | completed.
# Market order of | 1 GS sell | completed.
# Market order of | 1 GM sell | completed.
# We are taking a long position in: ['TSLA', 'SQ', 'QCOM', 'OKTA', 'NIO', 'TLRY', 'DOMO']
# We are taking a short position in: ['SPWR', 'CGC', 'GM', 'GS', 'RTN', 'SPLK', 'MRO']
# Market order of | 2 SPWR buy | completed.
# Market order of | 2 SPLK buy | completed.
# Market order of | 2 RTN buy | completed.
# Market order of | 2 MRO buy | completed.
# Market order of | 2 GS buy | completed.
# Market order of | 2 GM buy | completed.
# Order of | 43 CGC sell | did not go through.
# Market order of | 2 SPWR sell | completed.
# Market order of | 2 SPLK sell | completed.
# Market order of | 2 RTN sell | completed.
# Market order of | 2 MRO sell | completed.
# Market order of | 2 GS sell | completed.
# Market order of | 2 GM sell | completed.
# We are taking a long position in: ['PANW', 'SUN', 'QCOM', 'OKTA', 'SQ', 'TLRY', 'DOMO']
# We are taking a short position in: ['CGC', 'SPWR', 'GM', 'MRO', 'SPLK', 'SUI', 'CAT']
# Market order of | 105 TSLA sell | completed.
# Market order of | 106 TLRY buy | completed.
# Market order of | 106 SQ buy | completed.
# Market order of | 10 SPWR sell | completed.
# Market order of | 10 SPLK sell | completed.
# Market order of | 45 RTN buy | completed.
# Market order of | 106 QCOM buy | completed.
# Market order of | 106 OKTA buy | completed.
# Market order of | 105 NIO sell | completed.
# Market order of | 10 MRO sell | completed.
# Market order of | 45 GS buy | completed.
# Market order of | 10 GM sell | completed.
# Market order of | 106 DOMO buy | completed.
# Market order of | 211 PANW buy | completed.
# Market order of | 211 SUN buy | completed.
# Order of | 55 CGC sell | did not go through.
# Market order of | 55 SUI sell | completed.
# Market order of | 55 CAT sell | completed.
# Market order of | 3 SUI sell | completed.
# Market order of | 3 CAT sell | completed.
# Market order of | 3 SPWR sell | completed.
# Market order of | 3 SPLK sell | completed.
# Market order of | 3 MRO sell | completed.
# Market order of | 3 GM sell | completed.
# We are taking a long position in: ['OKTA', 'QCOM', 'SUN', 'TSLA', 'SQ', 'TLRY', 'DOMO']
# We are taking a short position in: ['SPWR', 'CGC', 'MRO', 'GM', 'SPLK', 'SUI', 'CAT']
# Market order of | 108 TLRY sell | completed.
# Market order of | 108 SUN sell | completed.
# Market order of | 3 SUI buy | completed.
# Market order of | 108 SQ sell | completed.
# Market order of | 3 SPWR buy | completed.
# Market order of | 3 SPLK buy | completed.
# Market order of | 108 QCOM sell | completed.
# Market order of | 211 PANW sell | completed.
# Market order of | 108 OKTA sell | completed.
# Market order of | 3 MRO buy | completed.
# Market order of | 3 GM buy | completed.
# Market order of | 108 DOMO sell | completed.
# Market order of | 3 CAT buy | completed.
# Market order of | 103 TSLA buy | completed.
# Order of | 55 CGC sell | did not go through.
# Market order of | 3 SUI sell | completed.
# Market order of | 3 SPWR sell | completed.
# Market order of | 3 SPLK sell | completed.
# Market order of | 3 MRO sell | completed.
# Market order of | 3 GM sell | completed.
# Market order of | 3 CAT sell | completed.
